# %%
import pandas as pd

path = '/home/zaccosenza/code/project-weather/data/01_raw/weather_data.csv'

df = pd.read_csv(path)
# Out:
# /tmp/ipykernel_203757/1802624122.py:5: DtypeWarning: Columns (2,3,4,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path)

# %%
df.iloc[0]
# Out:
# station                                                            LGA
# valid                                                 2000-01-01 00:00
# tmpf                                                             38.00
# dwpf                                                             34.00
# relh                                                             85.35
# drct                                                            210.00
# sknt                                                              5.00
# p01i                                                              0.00
# alti                                                             30.14
# mslp                                                           1020.60
# vsby                                                              8.00
# gust                                                                 M
# skyc1                                                                M
# ...
