# %%
import pandas as pd

path = '/home/zaccosenza/code/project-weather/data/04_inference/temperatures.parquet'
df = pd.read_parquet(path)

# %%
df
# Out:
#    year  month  day  hour  temperature            timestamp
# 0  2026      1   19    19         17.0  2026-01-19T19:00:00
# 1  2026      1   21     6         35.0  2026-01-21T06:00:00
